# %%
tup1=(23,43,54,12)
tup1=list(tup1)
tup1.append(43)
print(tuple(tup1))
# Out:
# (43, 12, 54, 23, 43)

# %%
x=("Information",)
print(type(x))
# Out:
# <class 'tuple'>

# %%
tup1=(23,43,54,12)
print("total",sum(tup1))
# Out:
# total 132

# %%
tup1=(23,43,54,12)
print("maximum",max(tup1))
# Out:
# maximum 54

# %%
tup1=(23,43,54,12)
print("min",min(tup1))
# Out:
# min 12

# %%
set1={23,43,84,94,32,23,84}
print(set1)
# Out:
# {32, 84, 23, 43, 94}

# %%
set1={12,34,29}
set2={34,11,30}
x=set1.union(set2)
print(x)
# Out:
# {34, 11, 12, 29, 30}

# %%
set1={12,34,29}
set2={34,11,30}
x=set1.intersection(set2)
print(x)
# Out:
# {34}

# %%
set1={12,34,29}
set2={34,11,30}
x=set1.difference(set2)
print(x)
# Out:
# {12, 29}

# %%
set1={12,34,29}
set2={34,11,30}
x=set1.symmetric_difference(set2)
print(x)
# Out:
# {11, 12, 29, 30}

# %%
set1={12,34,29,11,30}
set2={34,11,30}
x=set2.issubset(set1)
print(x)
# Out:
# True

# %%
set1={12,34,29,11,30}
set2={34,11,30}
x=set1.issuperset(set2)
print(x)
# Out:
# True

# %%
car={"Audi":4500,"BMW":7800,"scorpio":8392}
print(car)
print(type(car))
# Out:
# {'Audi': 4500, 'BMW': 7800, 'scorpio': 8392}
# <class 'dict'>

# %%
print("Audi",car["Audi"])
print("scopio",car["scorpio"])
# Out:
# Audi 4500
# scopio 8392

# %%
print("*"*30)
print("            cars details        ")
print("*"*30)
print("Audi    ",car["Audi"])
print("scopio    ",car["scorpio"])
print("*"*30)
grand_total=car["Audi"]+car["BMW"]+car["scorpio"]
print("grand total  ",grand_total)
# Out:
# ******************************
#             cars details
# ******************************
# Audi     4500
# scopio     8392
# ******************************
# grand total   20692

# %%
for i in car:
    print(i)
# Out:
# Audi
# BMW
# scorpio

# %%
for i in car:
    print(car[i])
# Out:
# 4500
# 7800
# 8392

# %%
for i in car.keys():
    print(i)
# Out:
# Audi
# BMW
# scorpio

# %%
for i in car.values():
    print(i)
# Out:
# 4500
# 7800
# 8392

# %%
for i,j in car.items():
    print(i,j)
# Out:
# Audi 4500
# BMW 7800
# scorpio 8392

# %%
car["alto"]=2300
print(car)
# Out:
# {'Audi': 4500, 'BMW': 7800, 'scorpio': 8392, 'alto': 2300}

# %%
employee={};
int n=int(input("enter no. of employee:  )
print("eneter the employees data:  )
for i in range(0,n):
# Out:
# <class 'dict'>
