# %%
def add(a,b):
    return a+b
print(add(2,3))
# Out:
# 5

# %%
x= lambda x,y,z:x+y*z+20
print(x(10,20,30))
def statement():
    print("Lambda function work properly")
statement();
# Out:
# 630
# Lambda function work properly

# %%
import pandas as pd
df=pd.read_excel("D:\Download\Practice.xlsx")
df
# Out:
#       name  subject      fee
# 0  Kuldeep     Math  10000.0
# 1    Rahul  English      NaN
# 2    mohan      NaN   3839.0
# 3    Shyam    Hindi   3000.0
# 4     Aman  Science      NaN

# %%
df1=df.dropna()
df1
# Out:
#       name subject      fee
# 0  Kuldeep    Math  10000.0
# 3    Shyam   Hindi   3000.0

# %%
df2=df.dropna(axis=1)
print(df2)
# Out:
#       name
# 0  Kuldeep
# 1    Rahul
# 2    mohan
# 3    Shyam
# 4     Aman

# %%
df3=df.fillna(0)
df3
# Out:
#       name  subject      fee
# 0  Kuldeep     Math  10000.0
# 1    Rahul  English      0.0
# 2    mohan        0   3839.0
# 3    Shyam    Hindi   3000.0
# 4     Aman  Science      0.0

# %%
df4=df.fillna(df["fee"].mean())
df4
# Out:
#       name  subject      fee
# 0  Kuldeep     Math  10000.0
# 1    Rahul  English   5613.0
# 2    mohan   5613.0   3839.0
# 3    Shyam    Hindi   3000.0
# 4     Aman  Science   5613.0

# %%
df5=df.bfill()
df5
# Out:
#       name  subject      fee
# 0  Kuldeep     Math  10000.0
# 1    Rahul  English   3839.0
# 2    mohan    Hindi   3839.0
# 3    Shyam    Hindi   3000.0
# 4     Aman  Science      NaN

# %%
df6=df.ffill()
df6
# Out:
#       name  subject      fee
# 0  Kuldeep     Math  10000.0
# 1    Rahul  English  10000.0
# 2    mohan  English   3839.0
# 3    Shyam    Hindi   3000.0
# 4     Aman  Science   3000.0

# %%
import pandas as pd
df=pd.read_csv("tested.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df1=df.dropna()
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2=df.dropna(axis=1)
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex  SibSp  Parch  \
# 0                                Kelly, Mr. James    male      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female      1      0
# 2                       Myles, Mr. Thomas Francis    male      0      0
# 3                                Wirz, Mr. Albert    male      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female      1      1
# ..                                            ...     ...    ...    ...
# ...

# %%
df3=df.fillna(39)
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
import pandas as pd
df=pd.DataFrame({"name":["Amit","rahul","soni","    mohan"]})
df
# Out:
#         name
# 0       Amit
# 1      rahul
# 2       soni
# 3      mohan

# %%
df["cap_name"]=df["name"].str.capitalize()
df
# Out:
#         name   cap_name
# 0       Amit       Amit
# 1      rahul      Rahul
# 2       soni       Soni
# 3      mohan      mohan

# %%
import pandas as pd
df=pd.DataFrame({"First_Name":["Amit","Shyam","Anjali","Rahul"],
                "Last_name":["sharma","prasad","Rai","pratap"]
})
df["Name"]=df["First_Name"]+" "+df["Last_name"]
print(df)
# Out:
#   First_Name Last_name          Name
# 0       Amit    sharma   Amit sharma
# 1      Shyam    prasad  Shyam prasad
# 2     Anjali       Rai    Anjali Rai
# 3      Rahul    pratap  Rahul pratap

# %%
df1=df["Name"].str.split(" ").str[1]
df1
# Out:
# 0    sharma
# 1    prasad
# 2       Rai
# 3    pratap
# Name: Name, dtype: object

# %%
import pandas as pd
df=pd.DataFrame({
    "Email":[
