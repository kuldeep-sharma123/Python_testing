# %%
import kagglehub

path = kagglehub.dataset_download("sobhanmoosavi/us-accidents")
print(path)
print("Path to dataset files:", path)
# Out:
# Downloading to C:\Users\KULDEEP SHARMA\.cache\kagglehub\datasets\sobhanmoosavi\us-accidents\13.archive...
# 100%|██████████| 653M/653M [00:58<00:00, 11.8MB/s]
# Extracting files...
# C:\Users\KULDEEP SHARMA\.cache\kagglehub\datasets\sobhanmoosavi\us-accidents\versions\13
# Path to dataset files: C:\Users\KULDEEP SHARMA\.cache\kagglehub\datasets\sobhanmoosavi\us-accidents\versions\13

# %%
import os
for root,dirs,files in os.walk(path):
    for file in files:
        print(file)
# Out:
# US_Accidents_March23.csv

# %%
import pandas as pd
import os

csv_file = os.path.join(path, "US_Accidents_March23.csv")

df = pd.read_csv(csv_file)

df.head()
