# %%
from datetime import datetime,timedelta,date
a=datetime.now()
print(a)
# Out:
# 2026-08-06 14:58:51.281559

# %%
x=a.strftime("%d %B %y")
print(x)
# Out:
# 06 August 26

# %%
b=date.today()
print(b)
# Out:
# 2026-08-06

# %%
next_date=b+timedelta(days=4)
print(next_date)
# Out:
# 2026-08-10
