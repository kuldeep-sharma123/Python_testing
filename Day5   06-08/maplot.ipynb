# %%
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import image as mpig
data={'Nutrition Drink':['Complan','Horliks','Pediasure','Milo'],
      'price':[200,300,750,800],
      'Quantity':[2,4,3,5]}
df=pd.DataFrame(data)
df['Total']=df['price']*df['Quantity']
df.to_excel(r'C:\Users\KULDEEP SHARMA\OneDrive\Desktop\shivani\nutritional_drink.xlsx',index=False,header=True)
print(df)

plt.title("Nutritional Drink")
plt.xlabel("X pixel scaling")
plt.ylabel("Y pixel scaling")

image=mpig.imread("Ensure-Enlive-nutritional-drink-for-seniors-1024x585.jpg")
plt.imshow(image)
plt.show()
# Out:
#   Nutrition Drink  price  Quantity  Total
# 0         Complan    200         2    400
# 1         Horliks    300         4   1200
# 2       Pediasure    750         3   2250
# 3            Milo    800         5   4000
