# %%
print("hello")
# Out:
# hello

# %%
fname=input("Enter your name: ")
print(fname);
# Out:
# Enter your name:  rahul
# rahul

# %%
num1=25
num2=2
print("total",num1+num2)
print("Diff: ",num1-num2)
print("multiplication:",num1*num2)
print("Division: ",num1/num2)
print("float division: ",num1//num2)
print("Reminder: ",num1%num2)
print("exponential: ",num1**num2)
# Out:
# total 27
# Diff:  23
# multiplication: 50
# Division:  12.5
# float division:  12
# Reminder:  1
# exponential:  625

# %%
num1=40
num1-=30
print(num1)
# Out:
# 10

# %%
a=20
b=30
print(a==b)
# Out:
# False

# %%
a=10
b=20
c=6
print(a>b and b>c)
# Out:
# False

# %%
cars=["honda city","Audi","BMW","Dzire"]
print(cars)
# Out:
# ['honda city', 'Audi', 'BMW', 'Dzire']

# %% [raw]
# print("my favouirate car is" cars[2]);

# %%
print("my favouirate car is", cars[2]);
# Out:
# my favouirate car is BMW

# %%
print(cars[-3:-1])
# Out:
# ['Audi', 'BMW']

# %%
cars=["honda city","Audi","BMW","Dzire"]
cars.append("fortuner")
cars.insert(1,"thar")

print(cars)
# Out:
# ['honda city', 'thar', 'Audi', 'BMW', 'Dzire', 'fortuner']

# %%
cars=["honda city","Audi","BMW","Dzire"]
cars_n=["jaguar","land rover"]
cars.extend(cars_n)
print(cars)
# Out:
# ['honda city', 'Audi', 'BMW', 'Dzire', 'jaguar', 'land rover']

# %%
cars.pop()
print(cars)
# Out:
# ['honda city', 'Audi', 'BMW', 'Dzire', 'jaguar']

# %%
cars.pop(2)
print(cars)
# Out:
# ['honda city', 'Audi']

# %%
cars=["honda city","Audi","BMW","Dzire"]
cars_n=["jaguar","land rover"]
cars.extend(cars_n)
del cars[2:4]
print(cars)
# Out:
# ['honda city', 'Audi', 'jaguar', 'land rover']

# %%
cars=["honda city","Audi","BMW","Dzire"]
cars_n=["jaguar","land rover"]
cars.extend(cars_n)
for i in cars:
    print(i)
# Out:
# honda city
# Audi
# BMW
# Dzire
# jaguar
# land rover

# %%
car_i=[]
for n in cars:
    if n=="i":
        car_i.append(n)
print(car_i)
# Out:
# []

# %%
car_i=[]
for n in cars:
    if "i" in n:
        car_i.append(n)
print(car_i)
# Out:
# ['honda city', 'Audi', 'Dzire']

# %%
x=[10,20,30,40,50]
a=[i**2 for i in x]
print(a)
# Out:
# [100, 400, 900, 1600, 2500]

# %%
x=[10,20,30,43,50]
a=[i**2 for i in x if i%2==0]
print(a)
# Out:
# [100, 400, 900, 2500]

# %%
cars=["honda city","Audi","BMW","Dzire","Amaze"]
car_n=[ x for x in cars if x.startswith("A")]
print(car_n)
# Out:
# ['Audi', 'Amaze']

# %%
Department=["HR","Acc-finance","HR-Admin","Acc-marketing","HR-oops","banking"]
HR_dept=[]
Acc_dept=[]
other=[]
for i in Department:
    if "HR" in i:
        HR_dept.append(i)
    elif "Acc" in i:
        Acc_dept.append(i)
    else:
        other.append(i)
print(HR_dept)
print(Acc_dept)
print(other)
# Out:
# ['HR', 'HR-Admin', 'HR-oops']
# ['Acc-finance', 'Acc-marketing']
# ['banking']
